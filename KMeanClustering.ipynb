# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
X = np.array([[2,10],[2,5],[8,4],[5,8],[7,5],[6,4],[1,2],[4,9]])

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Plot the data points and cluster centroids
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', alpha=0.7, edgecolors='k')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, linewidths=2, color='red', label='Centroids')
plt.title('K-means Clustering')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %%
labels
# Out:
# array([2, 0, 1, 2, 1, 1, 0, 2])

# %%
centroids
# Out:
# array([[1.5       , 3.5       ],
#        [7.        , 4.33333333],
#        [3.66666667, 9.        ]])

# %% [markdown]
# 2.Generate 1000 2D data points in the range 0-100 randomly.

# %%
np.random.seed(42)

# %%
data_points = np.random.randint(0,101, size=(1000,2))
data_points
# Out:
# array([[20, 63],
#        [36, 26],
#        [54, 28],
#        ...,
#        [89, 79],
#        [56, 76],
#        [14, 26]])

# %%
kmeans_cluster = KMeans(n_clusters=3)
kmeans_cluster.fit(data_points)
# Out:
# KMeans(n_clusters=3)

# %%
cluster_labels = kmeans_cluster.labels_
cluster_centers = kmeans_cluster.cluster_centers_

# %%
print(cluster_labels)
# Out:
# [2 2 0 2 1 2 1 2 0 0 2 0 2 1 0 1 1 2 1 0 2 2 0 1 0 2 1 2 0 1 2 1 2 1 0 1 0
#  1 2 1 0 0 2 2 0 1 2 2 1 1 1 0 1 1 2 2 1 2 1 0 0 1 2 2 0 0 2 0 0 1 0 2 0 1
#  2 0 1 0 2 1 1 1 0 2 1 0 2 2 2 1 2 1 1 2 1 0 0 2 0 0 2 1 0 0 1 2 2 2 0 0 1
#  0 1 1 2 1 2 0 2 2 2 1 2 1 0 0 0 1 1 0 2 0 2 1 1 2 1 1 0 0 1 0 1 0 1 1 2 1
#  0 1 0 1 2 0 2 1 1 0 0 2 0 2 2 1 0 1 1 1 1 2 1 2 2 0 0 1 1 2 2 2 0 2 2 1 1
#  0 0 2 1 2 2 2 2 1 0 0 0 1 2 1 1 2 2 2 0 1 2 0 1 2 0 0 1 0 1 1 1 2 1 1 2 2
#  0 2 1 2 2 1 2 1 1 0 2 0 2 2 0 2 1 1 2 2 2 1 2 2 2 1 1 2 0 0 1 1 2 1 1 1 1
#  0 2 1 1 2 2 0 1 2 0 0 2 1 2 0 1 2 1 1 0 0 2 2 0 1 2 1 0 2 0 2 1 0 1 1 2 0
#  1 1 1 2 2 1 2 2 0 2 0 2 0 1 2 1 0 1 2 1 2 1 0 0 1 0 1 2 2 2 2 2 2 0 2 1 1
#  1 2 1 1 0 1 0 2 0 1 2 0 1 0 0 1 1 1 2 0 2 1 0 1 2 1 0 1 1 2 2 2 1 1 1 1 0
#  2 2 0 1 1 0 0 0 2 0 1 1 1 1 2 1 2 1 2 0 2 1 0 0 0 1 2 0 0 1 2 1 2 2 0 2 0
#  0 1 0 2 1 1 1 2 1 0 1 2 0 2 0 2 0 0 2 0 2 1 2 2 2 1 1 2 0 2 2 0 1 1 2 0 1
# ...

# %%
print(cluster_centers)
# Out:
# [[76.67961165 31.88996764]
#  [50.36243386 81.96560847]
#  [22.04153355 32.22044728]]

# %%
plt.figure(figsize=(15,10))
plt.scatter(data_points[:, 0], data_points[:, 1], c=cluster_labels, cmap='viridis', alpha=0.5, edgecolors='w')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='X', s=200, label='Cluster Centers')
plt.title('K-Means Clustering')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()
